# %%
import pandas as pd
import os

# Define the path to the temporary results file
temp_results_path = 'temp_results.csv'

# Check if the temporary results file exists
if os.path.exists(temp_results_path):
    # Load the temporary results into a DataFrame
    temp_df = pd.read_csv(temp_results_path)
    print("Temporary results loaded successfully.")
else:
    print("Temporary results file does not exist.")
    
# Display the contents of the temporary results DataFrame
print(temp_df)

# Optionally, save the loaded temporary results to a new file if needed
output_file_path = 'saved_temp_results.xlsx'
temp_df.to_excel(output_file_path, index=False)
print("Temporary results saved to", output_file_path)
# Out:
# Temporary results loaded successfully.
#                  name Instagram Followers
# 0         Pilou Asbæk                512K
# 1     Martin Lawrence                 10M
# 2   Jennifer Connelly                  2M
# 3           Zac Efron                 62M
# 4          Gemma Chan                  2M
# ..                ...                 ...
# 75       Rory J Saper                 621
# 76       Maika Monroe                215K
# 77     Keir Gilchrist                485K
# 78        Naomi Watts                  2M
# 79      Ewan McGregor                 63K
#
# [80 rows x 2 columns]
# Temporary results saved to saved_temp_results.xlsx

# %%
import requests
from bs4 import BeautifulSoup
import re
import random
import time
import pandas as pd
import os

# We are going to search in google for the name of the Actor plus the word Instagram to get better results and with this take the number of followers of
# each actor.
# Put your user agent here
user_agents = [
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36; Sofia Villamil / sofia.v1999@gmail.com'    
]

def get_random_user_agent():
    return random.choice(user_agents)

def log_request_info(search_query, attempt, error=None):
    with open("scraping_log.txt", "a") as log_file:
        log_file.write(f"Attempt {attempt} for {search_query}\n")
        if error:
            log_file.write(f"Error: {error}\n")

def search_followers(search_query, retries=3):
    for attempt in range(retries):
        try:
            headers = {'User-Agent': get_random_user_agent()}
            search_url = f"https://www.google.com/search?q={search_query}"
            print(f"Searching for {search_query}: {search_url}")
            response = requests.get(search_url, headers=headers, timeout=10)
            
            log_request_info(search_query, attempt + 1)
            
            if response.status_code == 200:
                soup = BeautifulSoup(response.text, 'html.parser')
                
                # Using a flexible search for divs with class names that match the pattern
                result_elements = soup.find_all('div', class_=re.compile(r'VwiC3b.*yXK7lf.*r025kc.*hJNv6b'))
                
                for element in result_elements:
                    spans = element.find_all('span')
                    for span in spans:
                        span_text = span.get_text()
                        if "Followers" in span_text or "seguidores" in span_text:
                            match = re.search(r'(\d+(?:,\d+)*M|\d+(?:,\d+)*K|\d+(?:,\d+)*)', span_text)
                            if match:
                                followers = match.group(1)
                                followers = followers.replace(',', '')  # Clean the followers count
                                return followers
                
                print(f"Followers count not found in search results for {search_query}.")
                return None
            elif response.status_code == 429:
                print(f"Rate limited for {search_query}, status code: {response.status_code}")
                time.sleep(random.uniform(30, 60)) 
            else:
                print(f"Failed to retrieve search results for {search_query}, status code: {response.status_code}")
        
        except Exception as e:
            print(f"An error occurred for {search_query} on attempt {attempt + 1}: {e}")
            log_request_info(search_query, attempt + 1, error=str(e))
            if attempt < retries - 1:
                time.sleep(random.uniform(2, 5) * (2 ** attempt))  
            else:
                return None

def get_instagram_followers_from_google(name):
    followers = search_followers(f"{name} site:instagram.com")
    if not followers:
        print(f"Retrying with a different query for {name}")
        followers = search_followers(f"{name} Instagram")
    return followers

def process_names(names, start_index=0):
    results = []
    for i in range(start_index, len(names)):
        name = names[i]
        followers = get_instagram_followers_from_google(name)
        results.append((name, followers))
        time.sleep(random.uniform(10, 30))  
        
        # Save progress every 2 names
        if (i + 1) % 2 == 0:
            temp_df = pd.DataFrame(results, columns=['name', 'Instagram Followers'])
            temp_df.to_csv('temp_results.csv', index=False)
            print(f"Progress saved at index {i + 1}")
    
    return results

# Load the Excel file
file_path = r'C:/Users/sofia/Documents/Documentos/Master Computational Social Sciences/TFM/Master Thesis/Modeling Part 3/Youtube and Instagram Data/data_final_actores_full.xlsx'
df = pd.read_excel(file_path)

names = df['name'].tolist()

# Select names to scrap
names = names[:10]
# the limit for request is low, aproximatelly 80 names. So i did it in chuncks of 50 save it to a different excel and then join them manually.

if os.path.exists('temp_results.xlsx'):
    temp_df = pd.read_excel('temp_results.xlsx')
    processed_names = temp_df['name'].tolist()
    start_index = len(processed_names)
else:
    start_index = 0

followers_list = process_names(names[start_index:], start_index)

# Combine with previously processed data if any
if start_index > 0:
    previous_df = pd.read_excel('temp_results.xlsx')
    followers_df = pd.concat([previous_df, pd.DataFrame(followers_list, columns=['name', 'Instagram Followers'])], ignore_index=True)
else:
    followers_df = pd.DataFrame(followers_list, columns=['name', 'Instagram Followers'])

# Merge with original dataframe
df = df.merge(followers_df, on='name', how='left')

# Save back to an excel
output_file_path = r'C:/Users/sofia/Documents/Documentos/Master Computational Social Sciences/TFM/Master Thesis/Modeling Part 3/Youtube and Instagram Data/data_final_actores_full_2.xlsx'
df.to_excel(output_file_path, index=False)

print("Finished processing and saved to", output_file_path)
# Out:
# Searching for Rebel Wilson site:instagram.com: https://www.google.com/search?q=Rebel Wilson site:instagram.com
# Followers count not found in search results for Rebel Wilson site:instagram.com.
# Retrying with a different query for Rebel Wilson
# Searching for Rebel Wilson Instagram: https://www.google.com/search?q=Rebel Wilson Instagram
# Searching for Carrie-Anne Moss site:instagram.com: https://www.google.com/search?q=Carrie-Anne Moss site:instagram.com
# Progress saved at index 2
# Searching for Simon Pegg site:instagram.com: https://www.google.com/search?q=Simon Pegg site:instagram.com
# Searching for Nick Frost site:instagram.com: https://www.google.com/search?q=Nick Frost site:instagram.com
# Progress saved at index 4
# Searching for Chukwudi Iwuji site:instagram.com: https://www.google.com/search?q=Chukwudi Iwuji site:instagram.com
# Searching for Elizabeth Mitchell site:instagram.com: https://www.google.com/search?q=Elizabeth Mitchell site:instagram.com
# Progress saved at index 6
# Searching for Alex Russell site:instagram.com: https://www.google.com/search?q=Alex Russell site:instagram.com
# Searching for Nat Wolff site:instagram.com: https://www.google.com/search?q=Nat Wolff site:instagram.com
# Progress saved at index 8
# Searching for Alexandra Daddario site:instagram.com: https://www.google.com/search?q=Alexandra Daddario site:instagram.com
# Progress saved at index 62
# Searching for Sophie Nélisse site:instagram.com: https://www.google.com/search?q=Sophie Nélisse site:instagram.com
# Searching for Aaron Paul site:instagram.com: https://www.google.com/search?q=Aaron Paul site:instagram.com
# Progress saved at index 64
# Searching for Tilda Swinton site:instagram.com: https://www.google.com/search?q=Tilda Swinton site:instagram.com
# Searching for Paul Dano site:instagram.com: https://www.google.com/search?q=Paul Dano site:instagram.com
# Progress saved at index 66
# Searching for Vince Vaughn site:instagram.com: https://www.google.com/search?q=Vince Vaughn site:instagram.com
# Searching for Melanie Vallejo site:instagram.com: https://www.google.com/search?q=Melanie Vallejo site:instagram.com
# Progress saved at index 68
# Searching for Carrie Coon site:instagram.com: https://www.google.com/search?q=Carrie Coon site:instagram.com
# Searching for Kate Winslet site:instagram.com: https://www.google.com/search?q=Kate Winslet site:instagram.com
# Progress saved at index 70
# Searching for Kathryn Hahn site:instagram.com: https://www.google.com/search?q=Kathryn Hahn site:instagram.com
# Searching for Jack O'Connell site:instagram.com: https://www.google.com/search?q=Jack O'Connell site:instagram.com
# Progress saved at index 72
# Searching for Miyavi site:instagram.com: https://www.google.com/search?q=Miyavi site:instagram.com
# Searching for Jason Segel site:instagram.com: https://www.google.com/search?q=Jason Segel site:instagram.com
# Progress saved at index 74
# Searching for Cameron Diaz site:instagram.com: https://www.google.com/search?q=Cameron Diaz site:instagram.com
# Searching for Zoey Deutch site:instagram.com: https://www.google.com/search?q=Zoey Deutch site:instagram.com
# Progress saved at index 76
# Searching for Vicky Krieps site:instagram.com: https://www.google.com/search?q=Vicky Krieps site:instagram.com
# Searching for Cillian Murphy site:instagram.com: https://www.google.com/search?q=Cillian Murphy site:instagram.com
# Progress saved at index 78
# Searching for John Hurt site:instagram.com: https://www.google.com/search?q=John Hurt site:instagram.com
# Searching for Tom McGrath site:instagram.com: https://www.google.com/search?q=Tom McGrath site:instagram.com
# Rate limited for Tom McGrath site:instagram.com, status code: 429
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 107
#     104 else:
#     105     start_index = 0
# --> 107 followers_list = process_names(names[start_index:], start_index)
#     109 # Combine with previously processed data if any
#     110 if start_index > 0:
#
# Cell In[16], line 79, in process_names(names, start_index)
#      77 for i in range(start_index, len(names)):
#      78     name = names[i]
# ---> 79     followers = get_instagram_followers_from_google(name)
#      80     results.append((name, followers))
#      81     time.sleep(random.uniform(10, 30))
#
# Cell In[16], line 69, in get_instagram_followers_from_google(name)
#      68 def get_instagram_followers_from_google(name):
# ---> 69     followers = search_followers(f"{name} site:instagram.com")
#      70     if not followers:
#      71         print(f"Retrying with a different query for {name}")
#
# Cell In[16], line 56, in search_followers(search_query, retries)
#      54 elif response.status_code == 429:
#      55     print(f"Rate limited for {search_query}, status code: {response.status_code}")
# ---> 56     time.sleep(random.uniform(30, 60))
#      57 else:
#      58     print(f"Failed to retrieve search results for {search_query}, status code: {response.status_code}")
#
# KeyboardInterrupt:
